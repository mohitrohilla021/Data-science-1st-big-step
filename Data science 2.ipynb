# %% [markdown]
# # Pandas library, Series and DataFrame

# %% [markdown]
# # PANDAS

# %% [markdown]
# # Welcome again, let's get started...

# %%
# As the "jupyter" sees the "!" exclamation mark.
# it sends the rest of the line to the operating system for evaluation.
# !cat olympics.csv.

# %%
import pandas as pd

# %%
# pd.Series?

# %%
animals=['Lion','Tiger','Bear']
pd.Series(animals)
# Out:
# 0     Lion
# 1    Tiger
# 2     Bear
# dtype: object

# %%
numbers=['1','2','3']
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: object

# %%
animals=['Lion','Tiger',None]
pd.Series(animals)
# Out:
# 0     Lion
# 1    Tiger
# 2     None
# dtype: object

# %%
Number=['1','2',None]
pd.Series(Number)
# Out:
# 0       1
# 1       2
# 2    None
# dtype: object

# %%
import numpy as np

# %%
np.NaN==None
# Out:
# False

# %%
np.nan==None
# Out:
# False

# %%
np.nan==np.nan
# Out:
# False

# %%
np.isnan(np.nan)
# Out:
# True

# %%
sports={'Archery':'Bhutan',
       'Golf':'Scotland',
       'Sumo':'Japan',
       'Taekwondo':'South Korea'}
s=pd.Series(sports)
s
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
s.index
# Out:
# Index(['Archery', 'Golf', 'Sumo', 'Taekwondo'], dtype='object')

# %%
m=pd.Series(['Tiger','Bear','Moose'],index=['India','America','Canada'])
m
# Out:
# India      Tiger
# America     Bear
# Canada     Moose
# dtype: object

# %%
s.iloc[3]
# Out:
# 'South Korea'

# %%
s.loc['Golf']
# Out:
# 'Scotland'

# %%
s[3]
# Out:
# 'South Korea'

# %%
s['Golf']
# Out:
# 'Scotland'

# %%
s=pd.Series([100.00,120.00,101.00,3.00])

# %%
total=0
for item in s:
    total = total+ item
print(total)
# Out:
# 324.0

# %%
import numpy as np

# %%
total=np.sum(s)
total
# Out:
# 324.0

# %%
x=np.random.randint(0,1000,10000)
x
# Out:
# array([636, 562, 856, ..., 837, 577, 786])

# %%
x=pd.Series(x)
x
# Out:
# 0       638
# 1       564
# 2       858
# 3       435
# 4       593
#        ...
# 9995    695
# 9996    544
# 9997    839
# 9998    579
# 9999    788
# Length: 10000, dtype: int32

# %%
print("This is for tail:")
print(x.tail())
print("This is for head:")
print(x.head())
# Out:
# This is for tail:
# 9995    695
# 9996    544
# 9997    839
# 9998    579
# 9999    788
# dtype: int32
# This is for head:
# 0    638
# 1    564
# 2    858
# 3    435
# 4    593
# dtype: int32

# %%
len(x)
# Out:
# 10000

# %%
# %%timeit -n 100
summary=0
for item in x:
    summary += item
# Out:
# 10.1 ms ± 527 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 100
summary= np.sum(x)
# Out:
# 76 µs ± 31.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
s
# Out:
# 0    102.0
# 1    122.0
# 2    103.0
# 3      5.0
# dtype: float64

# %%
x
# Out:
# 0       638
# 1       564
# 2       858
# 3       435
# 4       593
#        ...
# 9995    695
# 9996    544
# 9997    839
# 9998    579
# 9999    788
# Length: 10000, dtype: int32

# %%
x += 2
x
# Out:
# 0       640
# 1       566
# 2       860
# 3       437
# 4       595
#        ...
# 9995    697
# 9996    546
# 9997    841
# 9998    581
# 9999    790
# Length: 10000, dtype: int32

# %%
#for label,value in x.iteritems():
#    print(label," hey ",value)
x.head();

# %%
# %%timeit -n 10
x=pd.Series(np.random.randint(0,1000,10000))
for label,value in x.iteritems():
    s.loc[label]=value+2
# Out:
# 1.48 s ± 362 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit -n 10
x=pd.Series(np.random.randint(0,1000,10000))
x=x+2

#in this way vectorization helps to do the things faster and better way...
# Out:
# 742 µs ± 145 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
ser=pd.Series(['1','2','3'])
ser.loc['You']='Coding champion'
ser
# Out:
# 0                    1
# 1                    2
# 2                    3
# You    Coding champion
# dtype: object

# %% [markdown]
# # DataFrame

# %%
import pandas as pd

# %%
purchase_1=pd.Series({'Name':'chris',
                     'Purchased':'Dog food',
                     'cost':22.50})
purchase_2=pd.Series({'Name':'Mohit',
                     'Purchased':'Chapati',
                     'cost':298.50})
purchase_3=pd.Series({'Name':'Rohit',
                     'Purchased':'Custurd',
                      'cost':32.50})
df = pd.DataFrame([purchase_1,purchase_2,purchase_3],index=['Store_1','Store_1','Store_2'])
df.head()
# Out:
#           Name Purchased   cost
# Store_1  chris  Dog food   22.5
# Store_1  Mohit   Chapati  298.5
# Store_2  Rohit   Custurd   32.5

# %%
df.loc['Store_2']
# Out:
# Name           Rohit
# Purchased    Custurd
# cost            32.5
# Name: Store_2, dtype: object

# %%
type(df.loc['Store_2'])
# Out:
# pandas.core.series.Series

# %%
df['Purchased']
# Out:
# Store_1    Dog food
# Store_1     Chapati
# Store_2     Custurd
# Name: Purchased, dtype: object

# %%
df.loc['Store_1','cost']
# Out:
# Store_1     22.5
# Store_1    298.5
# Name: cost, dtype: float64

# %%
df.T.loc['cost']
# Out:
# Store_1     22.5
# Store_1    298.5
# Store_2     32.5
# Name: cost, dtype: object

# %%
# iloc and loc are for selecting "row" selection...

# direct indexing operation is for column selection...

# %%
df['cost']
# Out:
# Store_1     22.5
# Store_1    298.5
# Store_2     32.5
# Name: cost, dtype: float64

# %%
df.loc[:,['Name','cost']]
# Out:
#           Name   cost
# Store_1  chris   22.5
# Store_1  Mohit  298.5
# Store_2  Rohit   32.5

# %%
df.drop("Store_1")
# Out:
#           Name Purchased  cost
# Store_2  Rohit   Custurd  32.5

# %%
df
# Out:
#           Name Purchased   cost
# Store_1  chris  Dog food   22.5
# Store_1  Mohit   Chapati  298.5
# Store_2  Rohit   Custurd   32.5

# %%
df_copy=df.copy()
df_copy=df_copy.drop('Store_1')
df_copy
# Out:
#           Name Purchased  cost
# Store_2  Rohit   Custurd  32.5

# %%
df
# Out:
#           Name Purchased   cost
# Store_1  chris  Dog food   22.5
# Store_1  Mohit   Chapati  298.5
# Store_2  Rohit   Custurd   32.5

# %%
df_copy
# Out:
#           Name Purchased  cost
# Store_2  Rohit   Custurd  32.5

# %%
del df_copy['Name']
df_copy
# Out:
#         Purchased  cost
# Store_2   Custurd  32.5

# %%
df
# Out:
#           Name Purchased   cost
# Store_1  chris  Dog food   22.5
# Store_1  Mohit   Chapati  298.5
# Store_2  Rohit   Custurd   32.5

# %%
df['location']=None
df
# Out:
#           Name Purchased   cost location
# Store_1  chris  Dog food   22.5     None
# Store_1  Mohit   Chapati  298.5     None
# Store_2  Rohit   Custurd   32.5     None

# %%
# df= pd.read_csv("File_name_here") 
# df.head()

# %%
df1=pd.read_csv("cars")
df1.head()

# %%
import os
path=os.getcwd()
print(path)
# Out:
# C:\Users\Rohit\AppData\Local\Programs\Python\Python38-32

# %%
df=pd.read_csv(r"E:\Mohit\Datasets\cars.csv")
df.head()
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
# 3                140                143               202
# 4                140                143               202
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# ...

# %%
df.columns
# Out:
# Index(['Dimensions.Height', 'Dimensions.Length', 'Dimensions.Width',
#        'Engine Information.Driveline', 'Engine Information.Engine Type',
#        'Engine Information.Hybrid',
#        'Engine Information.Number of Forward Gears',
#        'Engine Information.Transmission', 'Fuel Information.City mpg',
#        'Fuel Information.Fuel Type', 'Fuel Information.Highway mpg',
#        'Identification.Classification', 'Identification.ID',
#        'Identification.Make', 'Identification.Model Year',
#        'Identification.Year',
#        'Engine Information.Engine Statistics.Horsepower',
#        'Engine Information.Engine Statistics.Torque'],
#       dtype='object')

# %%
for col in df.columns:
    if col[:10]=='Editnsions':
        df.rename(columns={col:'Edit'+col[11:]},inplace=True)
df.head()
# Out:
#    EditHeight  EditLength  EditWidth Engine Information.Driveline  \
# 0         140         143        202              All-wheel drive
# 1         140         143        202            Front-wheel drive
# 2         140         143        202            Front-wheel drive
# 3         140         143        202              All-wheel drive
# 4         140         143        202              All-wheel drive
#
#                  Engine Information.Engine Type  Engine Information.Hybrid  \
# 0          Audi 3.2L 6 cylinder 250hp 236ft-lbs                       True
# 1  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo                       True
# 2  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo                       True
# 3  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo                       True
# 4  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo                       True
#
#    Engine Information.Number of Forward Gears Engine Information.Transmission  \
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv(r"E:\Mohit\Datasets\cars.csv")
df.head()
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
# 3                140                143               202
# 4                140                143               202
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# ...

# %%
df["Fuel Information.City mpg"]>20

# results are returned as boolean values, true or false...
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 5071    False
# 5072    False
# 5073    False
# 5074    False
# 5075    False
# Name: Fuel Information.City mpg, Length: 5076, dtype: bool

# %%
df
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 4                   140                143               202
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  \
# 0                 All-wheel drive
# 1               Front-wheel drive
# 2               Front-wheel drive
# 3                 All-wheel drive
# 4                 All-wheel drive
# ...

# %%
only_torque=df.where(df['Engine Information.Engine Statistics.Torque']>207)
only_torque.head()
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0              140.0              143.0             202.0
# 1                NaN                NaN               NaN
# 2                NaN                NaN               NaN
# 3                NaN                NaN               NaN
# 4                NaN                NaN               NaN
#
#   Engine Information.Driveline        Engine Information.Engine Type  \
# 0              All-wheel drive  Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1                          NaN                                   NaN
# 2                          NaN                                   NaN
# 3                          NaN                                   NaN
# 4                          NaN                                   NaN
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                        1.0                                         6.0
# ...

# %%
only_torque['Engine Information.Engine Statistics.Torque'].count()
# Out:
# 3611

# %%
df['Engine Information.Engine Statistics.Torque'].count()
# Out:
# 5076

# %%
only_torque=only_torque.dropna()
only_torque.head()
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0              140.0              143.0             202.0
# 5               91.0               17.0              62.0
# 6               91.0               17.0              62.0
# 7              201.0              221.0             191.0
# 8              201.0              221.0             191.0
#
#   Engine Information.Driveline          Engine Information.Engine Type  \
# 0              All-wheel drive    Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 5              All-wheel drive   Audi 3.2L 6 cylinder 265hp 243 ft-lbs
# 6              All-wheel drive   Audi 3.2L 6 cylinder 265hp 243 ft-lbs
# 7              All-wheel drive  Audi 4.2L 8 cylinder 350 hp 325 ft-lbs
# 8              All-wheel drive   Audi 3.6L 6 cylinder 280hp 266 ft-lbs
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                        1.0                                         6.0
# ...

# %%
only_torque['Engine Information.Engine Statistics.Torque'].count()
# Out:
# 3611

# %%
only_torque
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                 140.0              143.0             202.0
# 5                  91.0               17.0              62.0
# 6                  91.0               17.0              62.0
# 7                 201.0              221.0             191.0
# 8                 201.0              221.0             191.0
# ...                 ...                ...               ...
# 5071               13.0              253.0             201.0
# 5072              141.0              249.0             108.0
# 5073              160.0              249.0             108.0
# 5074              200.0              210.0             110.0
# 5075              200.0               94.0             110.0
#
#      Engine Information.Driveline  \
# 0                 All-wheel drive
# 5                 All-wheel drive
# 6                 All-wheel drive
# 7                 All-wheel drive
# 8                 All-wheel drive
# ...

# %%
len(df['Engine Information.Engine Statistics.Torque']>200)
# Out:
# 5076

# %%
df['Data']=df.index
df
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 4                   140                143               202
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  \
# 0                 All-wheel drive
# 1               Front-wheel drive
# 2               Front-wheel drive
# 3                 All-wheel drive
# 4                 All-wheel drive
# ...

# %%
df=df.set_index('Engine Information.Engine Statistics.Torque')
df.head()
# Out:
#                                              Dimensions.Height  \
# Engine Information.Engine Statistics.Torque
# 236                                                        140
# 207                                                        140
# 207                                                        140
# 207                                                        140
# 207                                                        140
#
#                                              Dimensions.Length  \
# Engine Information.Engine Statistics.Torque
# 236                                                        143
# 207                                                        143
# 207                                                        143
# 207                                                        143
# 207                                                        143
#
#                                              Dimensions.Width  \
# Engine Information.Engine Statistics.Torque
# ...

# %%
df=df.reset_index()
df.head()
# Out:
#    Engine Information.Engine Statistics.Torque  Dimensions.Height  \
# 0                                          236                140
# 1                                          207                140
# 2                                          207                140
# 3                                          207                140
# 4                                          207                140
#
#    Dimensions.Length  Dimensions.Width Engine Information.Driveline  \
# 0                143               202              All-wheel drive
# 1                143               202            Front-wheel drive
# 2                143               202            Front-wheel drive
# 3                143               202              All-wheel drive
# 4                143               202              All-wheel drive
#
#                  Engine Information.Engine Type  Engine Information.Hybrid  \
# 0          Audi 3.2L 6 cylinder 250hp 236ft-lbs                       True
# ...

# %%
df1=pd.read_csv(r"E:\Mohit\Datasets\datasets_14903_19895_india-districts-census-2011.csv")
df1
# Out:
#      District code                   State name              District name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
# ...

# %%
df1.head()
# Out:
#    District code         State name District name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Male_Literate  Female_Literate    SC  ...  \
# 0    439654         282823           156831  1048  ...
# 1    335649         207741           127908   368  ...
# 2     93770          62834            30936   488  ...
# 3     86236          56301            29935    18  ...
# 4    261724         163333            98391   556  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                            94                           588
# ...

# %%
# print(df1.to_string());

# %%
df1['District name'].unique()
# Out:
# array(['Kupwara', 'Badgam', 'Leh(Ladakh)', 'Kargil', 'Punch', 'Rajouri',
#        'Kathua', 'Baramula', 'Bandipore', 'Srinagar', 'Ganderbal',
#        'Pulwama', 'Shupiyan', 'Anantnag', 'Kulgam', 'Doda', 'Ramban',
#        'Kishtwar', 'Udhampur', 'Reasi', 'Jammu', 'Samba', 'Chamba',
#        'Kangra', 'Lahul AND Spiti', 'Kullu', 'Mandi', 'Hamirpur', 'Una',
#        'Bilaspur', 'Solan', 'Sirmaur', 'Shimla', 'Kinnaur', 'Gurdaspur',
#        'Kapurthala', 'Jalandhar', 'Hoshiarpur',
#        'Shahid Bhagat Singh Nagar', 'Fatehgarh Sahib', 'Ludhiana', 'Moga',
#        'Firozpur', 'Muktsar', 'Faridkot', 'Bathinda', 'Mansa', 'Patiala',
#        'Amritsar', 'Tarn Taran', 'Rupnagar', 'Sahibzada Ajit Singh Nagar',
#        'Sangrur', 'Barnala', 'Chandigarh', 'Uttarkashi', 'Chamoli',
#        'Rudraprayag', 'Tehri Garhwal', 'Dehradun', 'Garhwal',
#        'Pithoragarh', 'Bageshwar', 'Almora', 'Champawat', 'Nainital',
#        'Udham Singh Nagar', 'Hardwar', 'Panchkula', 'Ambala',
# ...

# %%
x=df1['State name'].unique()

import numpy as np

# %%
# df1=df1['Secondary_Education']>70000
# df1.head()

# %%
df1.head()
# Out:
#    District code         State name District name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Male_Literate  Female_Literate    SC  ...  \
# 0    439654         282823           156831  1048  ...
# 1    335649         207741           127908   368  ...
# 2     93770          62834            30936   488  ...
# 3     86236          56301            29935    18  ...
# 4    261724         163333            98391   556  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                            94                           588
# ...

# %%
df1.columns
# Out:
# Index(['District code', 'State name', 'District name', 'Population', 'Male',
#        'Female', 'Literate', 'Male_Literate', 'Female_Literate', 'SC',
#        ...
#        'Power_Parity_Rs_90000_150000', 'Power_Parity_Rs_45000_150000',
#        'Power_Parity_Rs_150000_240000', 'Power_Parity_Rs_240000_330000',
#        'Power_Parity_Rs_150000_330000', 'Power_Parity_Rs_330000_425000',
#        'Power_Parity_Rs_425000_545000', 'Power_Parity_Rs_330000_545000',
#        'Power_Parity_Above_Rs_545000', 'Total_Power_Parity'],
#       dtype='object', length=118)

# %%
columns_to_keep=['District code', 'State name', 'District name', 'Population', 'Male',
       'Female', 'Literate', 'Male_Literate', 'Female_Literate']

# %%
df1=df1[columns_to_keep]
df1.head()
# Out:
#    District code         State name District name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Male_Literate  Female_Literate
# 0    439654         282823           156831
# 1    335649         207741           127908
# 2     93770          62834            30936
# 3     86236          56301            29935
# 4    261724         163333            98391

# %%
df1
# Out:
#      District code                   State name              District name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
# ...

# %%
df1
# Out:
#      District code                   State name              District name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
# ...

# %%
df1=df1.T

# %%
df1
# Out:
#                                0                  1                  2    \
# District code                    1                  2                  3
# State name       JAMMU AND KASHMIR  JAMMU AND KASHMIR  JAMMU AND KASHMIR
# District name              Kupwara             Badgam        Leh(Ladakh)
# Population                  870354             753745             133487
# Male                        474190             398041              78971
# Female                      396164             355704              54516
# Literate                    439654             335649              93770
# Male_Literate               282823             207741              62834
# Female_Literate             156831             127908              30936
#
#                                3                  4                  5    \
# District code                    4                  5                  6
# State name       JAMMU AND KASHMIR  JAMMU AND KASHMIR  JAMMU AND KASHMIR
# ...

# %%
df1.head()
# Out:
#                              0                  1                  2    \
# District code                  1                  2                  3
# State name     JAMMU AND KASHMIR  JAMMU AND KASHMIR  JAMMU AND KASHMIR
# District name            Kupwara             Badgam        Leh(Ladakh)
# Population                870354             753745             133487
# Male                      474190             398041              78971
#
#                              3                  4                  5    \
# District code                  4                  5                  6
# State name     JAMMU AND KASHMIR  JAMMU AND KASHMIR  JAMMU AND KASHMIR
# District name             Kargil              Punch            Rajouri
# Population                140802             476835             642415
# Male                       77785             251899             345351
#
#                              6                  7                  8    \
# ...

# %%
# df2=df1[df1.loc['State name']=='HARYANA']

# %%
df2=df1.T

# %%
df2
# Out:
#     District code                   State name              District name  \
# 0               1            JAMMU AND KASHMIR                    Kupwara
# 1               2            JAMMU AND KASHMIR                     Badgam
# 2               3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3               4            JAMMU AND KASHMIR                     Kargil
# 4               5            JAMMU AND KASHMIR                      Punch
# ..            ...                          ...                        ...
# 635           636                  PONDICHERRY                       Mahe
# 636           637                  PONDICHERRY                   Karaikal
# 637           638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638           639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639           640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#     Population    Male  Female Literate Male_Literate Female_Literate
# ...

# %%
df2=df2[df2['State name']=='HARYANA']

# %%
df2.count()
# Out:
# District code      21
# State name         21
# District name      21
# Population         21
# Male               21
# Female             21
# Literate           21
# Male_Literate      21
# Female_Literate    21
# dtype: int64

# %%
df2
# Out:
#    District code State name District name Population    Male  Female Literate  \
# 68            69    HARYANA     Panchkula     561293  299679  261614   405318
# 69            70    HARYANA        Ambala    1128350  598703  529647   818025
# 70            71    HARYANA   Yamunanagar    1214205  646718  567487   832457
# 71            72    HARYANA   Kurukshetra     964655  510976  453679   646893
# 72            73    HARYANA       Kaithal    1074304  571003  503301   646529
# 73            74    HARYANA        Karnal    1505324  797712  707612   978013
# 74            75    HARYANA       Panipat    1205437  646857  558580   786599
# 75            76    HARYANA       Sonipat    1450001  781299  668702   998316
# 76            77    HARYANA          Jind    1334152  713006  621146   832758
# 77            78    HARYANA     Fatehabad     942011  495360  446651   557578
# 78            79    HARYANA         Sirsa    1295189  682582  612607   782897
# ...

# %%
df2=df2.set_index(['State name'])

# %%
df2.head()
# Out:
#            District code District name Population    Male  Female Literate  \
# State name
# HARYANA               69     Panchkula     561293  299679  261614   405318
# HARYANA               70        Ambala    1128350  598703  529647   818025
# HARYANA               71   Yamunanagar    1214205  646718  567487   832457
# HARYANA               72   Kurukshetra     964655  510976  453679   646893
# HARYANA               73       Kaithal    1074304  571003  503301   646529
#
#            Male_Literate Female_Literate
# State name
# HARYANA           229862          175456
# HARYANA           461288          356737
# HARYANA           474793          357664
# HARYANA           370828          276065
# HARYANA           385782          260747

# %%
df2
# Out:
#            District code District name Population    Male  Female Literate  \
# State name
# HARYANA               69     Panchkula     561293  299679  261614   405318
# HARYANA               70        Ambala    1128350  598703  529647   818025
# HARYANA               71   Yamunanagar    1214205  646718  567487   832457
# HARYANA               72   Kurukshetra     964655  510976  453679   646893
# HARYANA               73       Kaithal    1074304  571003  503301   646529
# HARYANA               74        Karnal    1505324  797712  707612   978013
# HARYANA               75       Panipat    1205437  646857  558580   786599
# HARYANA               76       Sonipat    1450001  781299  668702   998316
# HARYANA               77          Jind    1334152  713006  621146   832758
# HARYANA               78     Fatehabad     942011  495360  446651   557578
# HARYANA               79         Sirsa    1295189  682582  612607   782897
# ...

# %%
df2=df2.reset_index()

# %%
df2
# Out:
#    State name District code District name Population    Male  Female Literate  \
# 0     HARYANA            69     Panchkula     561293  299679  261614   405318
# 1     HARYANA            70        Ambala    1128350  598703  529647   818025
# 2     HARYANA            71   Yamunanagar    1214205  646718  567487   832457
# 3     HARYANA            72   Kurukshetra     964655  510976  453679   646893
# 4     HARYANA            73       Kaithal    1074304  571003  503301   646529
# 5     HARYANA            74        Karnal    1505324  797712  707612   978013
# 6     HARYANA            75       Panipat    1205437  646857  558580   786599
# 7     HARYANA            76       Sonipat    1450001  781299  668702   998316
# 8     HARYANA            77          Jind    1334152  713006  621146   832758
# 9     HARYANA            78     Fatehabad     942011  495360  446651   557578
# 10    HARYANA            79         Sirsa    1295189  682582  612607   782897
# ...

# %%
df2=df2.set_index(['State name','District code'])
df2
# Out:
#                          District name Population    Male  Female Literate  \
# State name District code
# HARYANA    69                Panchkula     561293  299679  261614   405318
#            70                   Ambala    1128350  598703  529647   818025
#            71              Yamunanagar    1214205  646718  567487   832457
#            72              Kurukshetra     964655  510976  453679   646893
#            73                  Kaithal    1074304  571003  503301   646529
#            74                   Karnal    1505324  797712  707612   978013
#            75                  Panipat    1205437  646857  558580   786599
#            76                  Sonipat    1450001  781299  668702   998316
#            77                     Jind    1334152  713006  621146   832758
#            78                Fatehabad     942011  495360  446651   557578
#            79                    Sirsa    1295189  682582  612607   782897
# ...

# %%
# df=df.sort_index()

# %% [markdown]
# for rows element access we have "loc" and "iloc"
# whereas for the column element access we have direct df['']...

# %% [markdown]
# # That's all for this session, have a good time ahead......
